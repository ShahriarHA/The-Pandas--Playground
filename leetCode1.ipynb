# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "user_id":[1,2],
    "name": ["aLicE","BOB"]
})

# %%
df
# Out:
#    user_id   name
# 0        1  aLicE
# 1        2    BOB

# %%
df["name"] = df.name.str.capitalize()

# %%
df
# Out:
#    user_id   name
# 0        1  Alice
# 1        2    Bob
